# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=150, n_features=1, noise=0.2)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([275.18171208])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
#python code demonstrate creating
#DataFreame from dict narray / lists
#by default addresses

import pandas as pd
data = {X :x,
        "Y" :y}
#create dataframe
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-17cd0cb35f11> in <module>
#       4
#       5 import pandas as pd
# ----> 6 data = {X :x,
#       7         "Y" :y}
#       8 #create dataframe
#
# NameError: name 'X' is not defined

# %%
reg.coef_

# %%
reg.intercept_

# %%
pyplot.scatter(X_test,y_test)
pyplot.show()

# %%
#python code demonstrate creating
#DataFrame from dict narray/ lists
#By default addresses.

import pandas as pd
data={'X':x,
      'y':y}

#Create DataFrame
df = pd.DataFrame(data)

# %%
df.head(20)

# %%
reg.coef_

# %%
reg.intercept_

# %%
pyplot.scatter(X_test,y_test)
y_plot = reg.coef_*X_test+reg.intercept_

pyplot.plot(X_test, y_plot, color='r')

pyplot.show()
